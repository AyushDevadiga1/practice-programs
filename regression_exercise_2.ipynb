# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
n = 100
p = 3
X = np.random.randn(n,p)
noise = np.random.rand(n)
X[:,2] = X[:,0] + 0.00001*noise

# %%
error = np.random.normal(0,0.1,n)

# %%
true_beta = np.array([11,6,2])

# %%
y = X @ true_beta + error

# %%
# Now we will calculate the condition number which is basically the stess test of the matrix test

# %%
np.linalg.cond(X.T@X)
# Out:
# np.float64(125631387028.35208)

# %%
# Why this much huge number because our feature X3 is the clone of X1 that's why.as the formula for condition number for a matrix_a : mod_a*a_inverse
