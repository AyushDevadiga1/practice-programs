# %%
class car:
    def __init__(self,model,color,no_plate):
        self.model = model
        self.car_color = color
        self.car_no_plate = no_plate
    
    def drive(self):
        return self.model+f' goes vroom'

# %%
car1 = car(
                model = 'Toyata',
                color = 'red',
                no_plate = 'MH-01-AY-0001'
)

# %%
car1.drive()
# Out:
# 'Toyata goes vroom'
