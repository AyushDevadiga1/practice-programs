# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('L1.csv')

# %%
df.plot(figsize=(10, 5))
plt.show()

# %%
# df.plot(kind='bar', figsize=(10, 6))
# plt.title("All Columns Bar Plot")
# plt.show()

# %%
# df.plot(kind='bar', stacked=True, figsize=(10, 6))
# plt.show()

# %%
df.plot(kind='bar', subplots=True, layout=(2, 2), figsize=(12, 8))
plt.tight_layout()
plt.show()
