# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
scalar_1 = [ 1, 5, -2 ]
# A set of scalars

# %%
# A set of vectors
v1 = np.array([1,5,8])
v2 = np.array([5,2,6])
v3 = np.array([5,2,7])

# %%
# To perform : we have to calculate the linear weighted combo
# first combine the vectors to a matrix

# %%
matrix_a = [ v1 , v2 , v3]

# %%
lin_wght_combo = np.zeros(len(v1))

# %%
for i,j in zip(matrix_a,scalar_1):
    lin_wght_combo += i*j

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lin_wght_combo
# Out:
# array([16., 11., 24.])

# %%
# The user now asks what happens if there are more scalars then vector lets try

# %%
scalar_1 = [ 1, 5, -2 , 4 ]

# %%
# We will try to use the same vector matrix and try to do it again

# %%
lin_weighted_matrix = np.zeros(len(v1))

# %%
for i,j in zip(matrix_a,scalar_1):
    lin_weighted_matrix = i*j

# %%
lin_weighted_matrix
# Out:
# array([-10,  -4, -14])

# %%
# Using zip() as above works, because zip() will use only the minimum-matching items.
# Re-writing the code using indexing will cause an error, as in the code below.

# %%
for i in range(len(scalar_1)):
    lin_weighted_matrix = scalar_1[i]*matrix_a[i]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 for i in range(len(scalar_1)):
# ----> 2     lin_weighted_matrix = scalar_1[i]*matrix_a[i]
#
# IndexError: list index out of range

# %%
# This of course doesnt work work because if you look closely the shapes of both wont match

# %%
# 1,4 and 3,3 cant create a matrix , why ?
# Because for any calculation we need j no of columnd of left matrix and i no of rows of a right matrix must be equal.

# %%
# FiRST we create a vector
v4 = np.array([1, 3])

# %%
# Then we are told to create 100 random sample from a unifrom distrbution in range -4 to  4

# %%
rand_100_uni = np.random.uniform(-4,4,100)

# %%
rand_100_uni # These are the random scalers
# Out:
# array([-1.550491  , -2.54525005,  1.77976726,  1.17675849,  1.11755067,
#        -0.31845527, -3.59852407,  2.60750431, -0.84214092,  1.15092289,
#         3.43529685,  0.1377479 , -3.41683706,  1.90630952,  1.53243516,
#        -2.55487185, -3.07061737, -3.22994736, -1.5785146 , -1.9083097 ,
#         2.89288493,  3.3838767 ,  0.44037992,  1.23989826,  0.44969191,
#        -2.26035341, -0.07027153,  3.29965963,  0.67223891,  2.73967274,
#         2.67163969, -3.06486937, -2.88672552, -0.07945414,  0.28310046,
#        -1.99192088, -1.41085054,  2.72721529,  3.25502079,  2.75694558,
#        -2.17807577,  2.21615469, -0.0099054 , -1.61656841,  3.59119744,
#         2.18206871, -2.60203702,  0.03712076,  1.72300598,  0.57544323,
#        -2.82822073, -0.68743701, -1.70055639, -3.53438897, -3.15660449,
#         3.45012484, -0.02569033,  2.35824004, -0.57680047,  3.2492052 ,
#        -1.75847098,  1.87904071,  2.89228243,  1.91150656, -1.60545988,
# ...

# %%
# Now we are told to multiply these vectors and create 100 random point in subspace

# %%
# Now we will multiply these scalars with the vector and draw it

# %%
for i in rand_100_uni:
    v4_new = v4 * i
    plt.plot(v4_new[0],v4_new[1],'ko')
plt.show()
